# %% [markdown]
# # Dropna & Fillna
# ## Dropna

# %%
import pandas as pd
csv=pd.read_csv("C:\\Users\\HP\\Desktop\\Pandas\\employees.csv")
csv
# Out:
#             Name          Profession               Post    Salary
# 0  Alice Johnson            Engineer    Senior Engineer  120000.0
# 1      Bob Smith              Doctor            Surgeon  150000.0
# 2  Charlie Brown                 NaN                NaN   80000.0
# 3    David White              Lawyer      Legal Advisor       NaN
# 4    Emma Wilson      Data Scientist        ML Engineer  140000.0
# 5    Faisal Khan  Software Developer  Backend Developer  110000.0
# 6      Grace Lee                 NaN   Graphic Designer       NaN
# 7   Hassan Ahmed          Accountant    Finance Manager       NaN
# 8    Isla Thomas               Nurse                NaN   85000.0
# 9     Jack Davis           Marketing        SEO Manager   95000.0

# %%
csv.dropna()
# Out:
#             Name          Profession               Post    Salary
# 0  Alice Johnson            Engineer    Senior Engineer  120000.0
# 1      Bob Smith              Doctor            Surgeon  150000.0
# 4    Emma Wilson      Data Scientist        ML Engineer  140000.0
# 5    Faisal Khan  Software Developer  Backend Developer  110000.0
# 9     Jack Davis           Marketing        SEO Manager   95000.0

# %%
csv.dropna(axis=0)
# Out:
#             Name          Profession               Post    Salary
# 0  Alice Johnson            Engineer    Senior Engineer  120000.0
# 1      Bob Smith              Doctor            Surgeon  150000.0
# 4    Emma Wilson      Data Scientist        ML Engineer  140000.0
# 5    Faisal Khan  Software Developer  Backend Developer  110000.0
# 9     Jack Davis           Marketing        SEO Manager   95000.0

# %%
csv.dropna(axis=1)
# Out:
#             Name
# 0  Alice Johnson
# 1      Bob Smith
# 2  Charlie Brown
# 3    David White
# 4    Emma Wilson
# 5    Faisal Khan
# 6      Grace Lee
# 7   Hassan Ahmed
# 8    Isla Thomas
# 9     Jack Davis

# %%
csv.dropna(how="any")
# Out:
#             Name          Profession               Post    Salary
# 0  Alice Johnson            Engineer    Senior Engineer  120000.0
# 1      Bob Smith              Doctor            Surgeon  150000.0
# 4    Emma Wilson      Data Scientist        ML Engineer  140000.0
# 5    Faisal Khan  Software Developer  Backend Developer  110000.0
# 9     Jack Davis           Marketing        SEO Manager   95000.0

# %%
 csv.dropna(subset=["Salary"])
# Out:
#             Name          Profession               Post    Salary
# 0  Alice Johnson            Engineer    Senior Engineer  120000.0
# 1      Bob Smith              Doctor            Surgeon  150000.0
# 2  Charlie Brown                 NaN                NaN   80000.0
# 4    Emma Wilson      Data Scientist        ML Engineer  140000.0
# 5    Faisal Khan  Software Developer  Backend Developer  110000.0
# 8    Isla Thomas               Nurse                NaN   85000.0
# 9     Jack Davis           Marketing        SEO Manager   95000.0

# %%
csv.dropna(inplace=True)
csv
# Out:
#             Name          Profession               Post    Salary
# 0  Alice Johnson            Engineer    Senior Engineer  120000.0
# 1      Bob Smith              Doctor            Surgeon  150000.0
# 4    Emma Wilson      Data Scientist        ML Engineer  140000.0
# 5    Faisal Khan  Software Developer  Backend Developer  110000.0
# 9     Jack Davis           Marketing        SEO Manager   95000.0

# %%
csv=pd.read_csv("C:\\Users\\HP\\Desktop\\Pandas\\employees.csv")
csv
# Out:
#             Name          Profession               Post    Salary
# 0  Alice Johnson            Engineer    Senior Engineer  120000.0
# 1      Bob Smith              Doctor            Surgeon  150000.0
# 2  Charlie Brown                 NaN                NaN   80000.0
# 3    David White              Lawyer      Legal Advisor       NaN
# 4    Emma Wilson      Data Scientist        ML Engineer  140000.0
# 5    Faisal Khan  Software Developer  Backend Developer  110000.0
# 6      Grace Lee                 NaN   Graphic Designer       NaN
# 7   Hassan Ahmed          Accountant    Finance Manager       NaN
# 8    Isla Thomas               Nurse                NaN   85000.0
# 9     Jack Davis           Marketing        SEO Manager   95000.0

# %%
csv.dropna(subset="Post")
# Out:
#             Name          Profession               Post    Salary
# 0  Alice Johnson            Engineer    Senior Engineer  120000.0
# 1      Bob Smith              Doctor            Surgeon  150000.0
# 3    David White              Lawyer      Legal Advisor       NaN
# 4    Emma Wilson      Data Scientist        ML Engineer  140000.0
# 5    Faisal Khan  Software Developer  Backend Developer  110000.0
# 6      Grace Lee                 NaN   Graphic Designer       NaN
# 7   Hassan Ahmed          Accountant    Finance Manager       NaN
# 9     Jack Davis           Marketing        SEO Manager   95000.0

# %% [markdown]
# ## Fillna

# %%
csv.fillna("Python")
csv
# Out:
#             Name          Profession               Post    Salary
# 0  Alice Johnson            Engineer    Senior Engineer  120000.0
# 1      Bob Smith              Doctor            Surgeon  150000.0
# 2  Charlie Brown                 NaN                NaN   80000.0
# 3    David White              Lawyer      Legal Advisor       NaN
# 4    Emma Wilson      Data Scientist        ML Engineer  140000.0
# 5    Faisal Khan  Software Developer  Backend Developer  110000.0
# 6      Grace Lee                 NaN   Graphic Designer       NaN
# 7   Hassan Ahmed          Accountant    Finance Manager       NaN
# 8    Isla Thomas               Nurse                NaN   85000.0
# 9     Jack Davis           Marketing        SEO Manager   95000.0

# %%
csv.fillna({"Profession":"Java","Post":"C","Salary":"0000"})
# Out:
#             Name          Profession               Post    Salary
# 0  Alice Johnson            Engineer    Senior Engineer  120000.0
# 1      Bob Smith              Doctor            Surgeon  150000.0
# 2  Charlie Brown                Java                  C   80000.0
# 3    David White              Lawyer      Legal Advisor      0000
# 4    Emma Wilson      Data Scientist        ML Engineer  140000.0
# 5    Faisal Khan  Software Developer  Backend Developer  110000.0
# 6      Grace Lee                Java   Graphic Designer      0000
# 7   Hassan Ahmed          Accountant    Finance Manager      0000
# 8    Isla Thomas               Nurse                  C   85000.0
# 9     Jack Davis           Marketing        SEO Manager   95000.0

# %%
csv=pd.read_csv("C:\\Users\\HP\\Desktop\\Pandas\\employees.csv")
csv
# Out:
#             Name          Profession               Post    Salary
# 0  Alice Johnson            Engineer    Senior Engineer  120000.0
# 1      Bob Smith              Doctor            Surgeon  150000.0
# 2  Charlie Brown                 NaN                NaN   80000.0
# 3    David White              Lawyer      Legal Advisor       NaN
# 4    Emma Wilson      Data Scientist        ML Engineer  140000.0
# 5    Faisal Khan  Software Developer  Backend Developer  110000.0
# 6      Grace Lee                 NaN   Graphic Designer       NaN
# 7   Hassan Ahmed          Accountant    Finance Manager       NaN
# 8    Isla Thomas               Nurse                NaN   85000.0
# 9     Jack Davis           Marketing        SEO Manager   95000.0

# %%
csv.ffill()
# Out:
#             Name          Profession               Post    Salary
# 0  Alice Johnson            Engineer    Senior Engineer  120000.0
# 1      Bob Smith              Doctor            Surgeon  150000.0
# 2  Charlie Brown              Doctor            Surgeon   80000.0
# 3    David White              Lawyer      Legal Advisor   80000.0
# 4    Emma Wilson      Data Scientist        ML Engineer  140000.0
# 5    Faisal Khan  Software Developer  Backend Developer  110000.0
# 6      Grace Lee  Software Developer   Graphic Designer  110000.0
# 7   Hassan Ahmed          Accountant    Finance Manager  110000.0
# 8    Isla Thomas               Nurse    Finance Manager   85000.0
# 9     Jack Davis           Marketing        SEO Manager   95000.0

# %%
csv.bfill()
# Out:
#             Name          Profession               Post    Salary
# 0  Alice Johnson            Engineer    Senior Engineer  120000.0
# 1      Bob Smith              Doctor            Surgeon  150000.0
# 2  Charlie Brown              Lawyer      Legal Advisor   80000.0
# 3    David White              Lawyer      Legal Advisor  140000.0
# 4    Emma Wilson      Data Scientist        ML Engineer  140000.0
# 5    Faisal Khan  Software Developer  Backend Developer  110000.0
# 6      Grace Lee          Accountant   Graphic Designer   85000.0
# 7   Hassan Ahmed          Accountant    Finance Manager   85000.0
# 8    Isla Thomas               Nurse        SEO Manager   85000.0
# 9     Jack Davis           Marketing        SEO Manager   95000.0

# %%
csv.bfill(axis=1)
# Out:
#             Name          Profession               Post    Salary
# 0  Alice Johnson            Engineer    Senior Engineer  120000.0
# 1      Bob Smith              Doctor            Surgeon  150000.0
# 2  Charlie Brown             80000.0            80000.0   80000.0
# 3    David White              Lawyer      Legal Advisor       NaN
# 4    Emma Wilson      Data Scientist        ML Engineer  140000.0
# 5    Faisal Khan  Software Developer  Backend Developer  110000.0
# 6      Grace Lee    Graphic Designer   Graphic Designer       NaN
# 7   Hassan Ahmed          Accountant    Finance Manager       NaN
# 8    Isla Thomas               Nurse            85000.0   85000.0
# 9     Jack Davis           Marketing        SEO Manager   95000.0

# %%
csv.ffill(axis=1)
# Out:
#             Name          Profession               Post            Salary
# 0  Alice Johnson            Engineer    Senior Engineer          120000.0
# 1      Bob Smith              Doctor            Surgeon          150000.0
# 2  Charlie Brown       Charlie Brown      Charlie Brown           80000.0
# 3    David White              Lawyer      Legal Advisor     Legal Advisor
# 4    Emma Wilson      Data Scientist        ML Engineer          140000.0
# 5    Faisal Khan  Software Developer  Backend Developer          110000.0
# 6      Grace Lee           Grace Lee   Graphic Designer  Graphic Designer
# 7   Hassan Ahmed          Accountant    Finance Manager   Finance Manager
# 8    Isla Thomas               Nurse              Nurse           85000.0
# 9     Jack Davis           Marketing        SEO Manager           95000.0

# %%
csv.fillna(12,inplace=True)
csv
# Out:
#             Name          Profession               Post    Salary
# 0  Alice Johnson            Engineer    Senior Engineer  120000.0
# 1      Bob Smith              Doctor            Surgeon  150000.0
# 2  Charlie Brown                  12                 12   80000.0
# 3    David White              Lawyer      Legal Advisor      12.0
# 4    Emma Wilson      Data Scientist        ML Engineer  140000.0
# 5    Faisal Khan  Software Developer  Backend Developer  110000.0
# 6      Grace Lee                  12   Graphic Designer      12.0
# 7   Hassan Ahmed          Accountant    Finance Manager      12.0
# 8    Isla Thomas               Nurse                 12   85000.0
# 9     Jack Davis           Marketing        SEO Manager   95000.0

# %%
csv=pd.read_csv("C:\\Users\\HP\\Desktop\\Pandas\\employees.csv")
csv.fillna("Python",limit=1)
# Out:
#             Name          Profession               Post    Salary
# 0  Alice Johnson            Engineer    Senior Engineer  120000.0
# 1      Bob Smith              Doctor            Surgeon  150000.0
# 2  Charlie Brown              Python             Python   80000.0
# 3    David White              Lawyer      Legal Advisor    Python
# 4    Emma Wilson      Data Scientist        ML Engineer  140000.0
# 5    Faisal Khan  Software Developer  Backend Developer  110000.0
# 6      Grace Lee                 NaN   Graphic Designer       NaN
# 7   Hassan Ahmed          Accountant    Finance Manager       NaN
# 8    Isla Thomas               Nurse                NaN   85000.0
# 9     Jack Davis           Marketing        SEO Manager   95000.0
